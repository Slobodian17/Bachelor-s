# %%
# !pip install mpi4py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.3/466.3 kB 12.5 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-4.0.3-cp310-cp310-linux_x86_64.whl size=4253357 sha256=0d11e9788e2dcea8a9854d8b477be2596acdacef721655ddddcaa85a8fab43bc
#   Stored in directory: /root/.cache/pip/wheels/94/57/cc/2e34c76a8690ce2a90b200702473f579b23f8224b5058b6a6d
# Successfully built mpi4py
# ...

# %%
# !rm -rf /kaggle/working/*

# %%
# !mpiexec --allow-run-as-root -n 2 python '/kaggle/input/mpi-parallel-cnn-py/MPI_Parallel.py'
# Out:
# 2025-03-07 10:43:40.241902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-07 10:43:40.241928: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-07 10:43:40.435169: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-07 10:43:40.435165: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
